# %% [markdown]
# # Fine-Tuning BERT4RE using PEFT on the App Review Dataset
#
# ### Importing required libraries

# %%
from datasets import load_dataset, DatasetDict, Dataset

from transformers import (
    AutoTokenizer,
    AutoConfig,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    TrainingArguments,
    Trainer)

from peft import PeftModel, PeftConfig, get_peft_model, LoraConfig
import evaluate
import torch
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_fscore_support, classification_report
import matplotlib.pyplot as plt
from transformers import EarlyStoppingCallback
import torch
# Out:
# 2024-08-06 04:14:31.402633: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-06 04:14:31.426031: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-06 04:14:31.433139: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-06 04:14:31.452636: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-06 04:14:36.407364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Exploring the dataset and preprocessing
#
# Here we concatenate two datasets. 4000 instances are manually annoated and the remaining 16000 are generated by ChatGPT through prompt fine-tuning

# %%
df1 = pd.read_excel('Data_Datasets_Unbalanced_dataset_unbalanced_4000.xlsx')
df2 = pd.read_excel('dataset_gpt_unbalanced_16000.xlsx')

df = pd.concat([df1, df2], ignore_index=True)
df.head()
# Out:
#    ID                                             review       label  \
# 0   1  Not able to add freinds. It show something wen...  bug report
# 1   2  Calls keep dropping for no reason and is super...  bug report
# 2   3  Can't access to my account solve this issue im...  bug report
# 3   4  I don't know what's wrong with my own WhatsApp...  bug report
# 4   5             Cannot record audio while taking video  bug report
#
#    new_label                               remove_all_stopwords  \
# 0          0  able add freinds show something went wrong rec...
# 1          0          calls keep dropping reason super annoying
# 2          0        cant access account solve issue immediately
# 3          0  dont know whats wrong whatsapp working want si...
# 4          0                   cannot record audio taking video
#
#                                remove_some_stopwords  \
# 0  not able add freinds show something went wrong...
# 1       calls keep dropping no reason super annoying
# 2        cant access account solve issue immediately
# 3  dont know whats wrong whatsapp not working wan...
# 4                   cannot record audio taking video
#
#                                             stemming  \
# 0  not abl to add freind it show someth went wron...
# 1    call keep drop for no reason and is super annoy
# 2     cant access to my account solv thi issu immedi
# 3  i dont know what wrong with my own whatsapp it...
# 4               cannot record audio while take video
#
#                                        lemmatization no_stopwords
# 0  not able to add freinds it show something went...          NaN
# 1  call keep dropping for no reason and is super ...          NaN
# 2  cant access to my account solve this issue imm...          NaN
# 3  i dont know whats wrong with my own whatsapp i...          NaN
# 4             cannot record audio while taking video          NaN

# %%
plt.figure(figsize=(5, 5))

# Get class labels and counts
# class_labels = df['label'].unique()
class_counts = df['label'].value_counts()
print(class_counts)

labels = []
counts = []
for label, count in class_counts.items():
    labels.append(label)
    counts.append(count)

# Create the bar plot
plt.bar(labels, counts, alpha=0.7)

# Annotate bars with exact values
for i, value in enumerate(class_counts):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom', fontsize=12)

# Set labels and title
plt.title('Histogram of Class Distribution')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.grid(True)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

plt.show()
# Out:
# user experience    6593
# rating             5740
# feature request    4410
# bug report         3257
# Name: label, dtype: int64

# %%
df = df.drop(columns=['label'])
df = df.rename(columns={'new_label': 'label'})

# %%
df = df.drop(columns=['remove_all_stopwords', 'remove_some_stopwords', 'stemming', 'lemmatization', 'no_stopwords'])

# %%
df.head()
# Out:
#    ID                                             review  label
# 0   1  Not able to add freinds. It show something wen...      0
# 1   2  Calls keep dropping for no reason and is super...      0
# 2   3  Can't access to my account solve this issue im...      0
# 3   4  I don't know what's wrong with my own WhatsApp...      0
# 4   5             Cannot record audio while taking video      0

# %%
missing_reviews = df['review'].isnull()
print(missing_reviews.sum())
# Out:
# 1

# %%
df = df.dropna(subset=['review'])

# %%
df['review'].isnull().sum()
# Out:
# 0

# %%
df['label'].unique()
# Out:
# array([0, 1, 3, 2])

# %%
id2label = {0: 'bug report', 1: 'feature request', 2: 'rating', 3: 'user experience'}
label2id = {label: id for id, label in id2label.items()}

# %%
df = df.sample(frac=1, random_state=42)

# %%
df.head()
# Out:
#           ID                                             review  label
# 10650  21459  Great emulator This is probably the best emula...      2
# 2041    2042                  it would be nice having new shows      1
# 8668   14560  Super App! Deeply-featured card search with pr...      1
# 1114    1115  Whenever atomic_number_53 try to open the app ...      0
# 13902  19254  !!!!!! ?????!!!!!! This app is a must have! Do...      2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19999 entries, 10650 to 15796
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      19999 non-null  int64
#  1   review  19999 non-null  object
#  2   label   19999 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 625.0+ KB

# %% [markdown]
# Here we split the data into training(80%), validation(10%) and testing(10%)

# %%
# Split the data into training, testing and validation sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(test_df, test_size=0.5, random_state=42)

# %%
train_dataset = Dataset.from_dict(train_df)
test_dataset = Dataset.from_dict(test_df)
val_dataset = Dataset.from_dict(val_df)
dataset = DatasetDict({"train":train_dataset,"test":test_dataset, "validation": val_dataset})

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['ID', 'review', 'label'],
#         num_rows: 15999
#     })
#     test: Dataset({
#         features: ['ID', 'review', 'label'],
#         num_rows: 2000
#     })
#     validation: Dataset({
#         features: ['ID', 'review', 'label'],
#         num_rows: 2000
#     })
# })

# %% [markdown]
# Here we load BERT4RE Base Uncased. BERT4RE is a domain-specific language model (LM) designed to support various requirements engineering (RE) tasks, including requirements classification, detection of language issues, identification of domain concepts, and establishment of requirements traceability links. BERT4RE is retrained from the generic BERTbase model using publicly available RE-related texts.

# %%
model_checkpoint = 'thearod5/bert4re'

# generate classification model from model_checkpoint
model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint, num_labels=4, id2label=id2label, label2id=label2id)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at thearod5/bert4re and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model
# Out:
# RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(32000, 768, padding_idx=1)
#       (position_embeddings): Embedding(514, 768, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-5): 6 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=4, bias=True)
#   )
# )

# %% [markdown]
# Here we load the tokenizer for our BERT4RE model. We use both padding and truncation and set the max length of tokenized text to 512

# %%
# create tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, add_prefix_space=True)

# add pad token if none exists
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': '[PAD]'})
    model.resize_token_embeddings(len(tokenizer))

# create tokenize function
def tokenize_function(examples):
    # extract text
    text = examples["review"]

    #tokenize and truncate text
    tokenizer.truncation_side = "left"
    tokenized_inputs = tokenizer(
        text,
        return_tensors="np",
        truncation=True,
        max_length=512
    )

    return tokenized_inputs

# %%
# tokenize training and validation datasets
tokenized_dataset = dataset.map(tokenize_function, batched=True)
tokenized_dataset
# Out:
# Map:   0%|          | 0/15999 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['ID', 'review', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 15999
#     })
#     test: Dataset({
#         features: ['ID', 'review', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 2000
#     })
#     validation: Dataset({
#         features: ['ID', 'review', 'label', 'input_ids', 'attention_mask'],
#         num_rows: 2000
#     })
# })

# %%
# create data collator
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
# import accuracy evaluation metric
accuracy = evaluate.load("accuracy")


# define an evaluation function to pass into trainer later
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=1)

    return {"accuracy": accuracy.compute(predictions=predictions, references=labels)}

# %% [markdown]
# ### Creating a parameter grid for finding optimal hyperparameters using Grid Search

# %%
# Define the parameter grid
param_grid = {
    'learning_rate': [1e-8, 1e-4, 1e-2],
    'weight_decay': [0.01, 0.05, 0.1],
    'lora_alpha': [16, 32, 64],
}

# %%
from sklearn.model_selection import ParameterGrid

# Convert param_grid to list of dictionaries
grid = list(ParameterGrid(param_grid))

# %%
grid
# Out:
# [{'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.01},
#  {'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.05},
#  {'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.1},
#  {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.01},
#  {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.05},
#  {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.1},
#  {'learning_rate': 1e-08, 'lora_alpha': 64, 'weight_decay': 0.01},
#  {'learning_rate': 1e-08, 'lora_alpha': 64, 'weight_decay': 0.05},
#  {'learning_rate': 1e-08, 'lora_alpha': 64, 'weight_decay': 0.1},
#  {'learning_rate': 0.0001, 'lora_alpha': 16, 'weight_decay': 0.01},
#  {'learning_rate': 0.0001, 'lora_alpha': 16, 'weight_decay': 0.05},
#  {'learning_rate': 0.0001, 'lora_alpha': 16, 'weight_decay': 0.1},
#  {'learning_rate': 0.0001, 'lora_alpha': 32, 'weight_decay': 0.01},
#  {'learning_rate': 0.0001, 'lora_alpha': 32, 'weight_decay': 0.05},
#  {'learning_rate': 0.0001, 'lora_alpha': 32, 'weight_decay': 0.1},
#  {'learning_rate': 0.0001, 'lora_alpha': 64, 'weight_decay': 0.01},
#  {'learning_rate': 0.0001, 'lora_alpha': 64, 'weight_decay': 0.05},
#  {'learning_rate': 0.0001, 'lora_alpha': 64, 'weight_decay': 0.1},
#  {'learning_rate': 0.01, 'lora_alpha': 16, 'weight_decay': 0.01},
#  {'learning_rate': 0.01, 'lora_alpha': 16, 'weight_decay': 0.05},
#  {'learning_rate': 0.01, 'lora_alpha': 16, 'weight_decay': 0.1},
#  {'learning_rate': 0.01, 'lora_alpha': 32, 'weight_decay': 0.01},
#  {'learning_rate': 0.01, 'lora_alpha': 32, 'weight_decay': 0.05},
#  {'learning_rate': 0.01, 'lora_alpha': 32, 'weight_decay': 0.1},
#  {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.01},
#  {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.05},
#  {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.1}]

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Following is a function to train and evaluate a model with certain hyperparamters passed in the function parameters. This function will be used in our grid search

# %%
def train_and_evaluate(params, model):
    # LoRA config
    peft_config = LoraConfig(task_type="SEQ_CLS",
                        r=4,
                        lora_alpha=params['lora_alpha'],
                        lora_dropout=0.1,
                        target_modules = ["attention.self.query", "attention.self.key","attention.self.value"])
    
    model = get_peft_model(model, peft_config)
    model.print_trainable_parameters()
    
    # Check if GPU is available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Add EarlyStoppingCallback to the trainer
    early_stopping = EarlyStoppingCallback(early_stopping_patience=3)
    
    # Create training arguments
    training_args = TrainingArguments(
        output_dir= model_checkpoint + "-lora-text-classification",
        learning_rate=params['learning_rate'],
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        num_train_epochs=20,
        weight_decay=params['weight_decay'],
        evaluation_strategy="epoch",
        save_strategy="epoch",
        load_best_model_at_end=True,
        lr_scheduler_type="cosine",  # learning rate scheduler type
        warmup_ratio=0.1  # warmup ratio for lr scheduler
    )

    # Create the Trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
        callbacks=[early_stopping]
    )

    # Train the model
    trainer.train()


    # Evaluate the model on the test set
    test_result = trainer.evaluate(eval_dataset=tokenized_dataset["test"])
    return test_result

# %% [markdown]
# Following is the code that performs the grid search and finds out the best setting

# %%
from tqdm.notebook import tqdm
# Perform grid search
best_score = float('-inf')
best_params = None
results = []

for params in tqdm(grid):
    print(f"Evaluating {params}...")
    result = train_and_evaluate(params, model)
    results.append((params, result))
    
    if result['eval_accuracy']['accuracy'] > best_score:
        best_score = result['eval_accuracy']['accuracy']
        best_params = params

print(f"Best params: {best_params}")
print(f"Best score: {best_score}")
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.01}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 20:47, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449995</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443400</td>
#       <td>1.446848</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442821</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439200</td>
#       <td>1.438960</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434700</td>
#       <td>1.435269</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432700</td>
#       <td>1.431834</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427800</td>
#       <td>1.428728</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425500</td>
#       <td>1.425942</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420600</td>
#       <td>1.423454</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420600</td>
#       <td>1.421341</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.420000</td>
#       <td>1.419525</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.418000</td>
#       <td>1.418033</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416300</td>
#       <td>1.416818</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414600</td>
#       <td>1.415902</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.416000</td>
#       <td>1.415255</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414300</td>
#       <td>1.414835</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413900</td>
#       <td>1.414647</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413800</td>
#       <td>1.414586</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412300</td>
#       <td>1.414575</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.414000</td>
#       <td>1.414575</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.05}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 20:42, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449995</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443400</td>
#       <td>1.446848</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442822</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439200</td>
#       <td>1.438962</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434700</td>
#       <td>1.435271</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432700</td>
#       <td>1.431836</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427800</td>
#       <td>1.428730</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425500</td>
#       <td>1.425944</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420600</td>
#       <td>1.423455</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420600</td>
#       <td>1.421341</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.420000</td>
#       <td>1.419526</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.418000</td>
#       <td>1.418033</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416300</td>
#       <td>1.416818</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414600</td>
#       <td>1.415901</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.416000</td>
#       <td>1.415255</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414300</td>
#       <td>1.414834</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413900</td>
#       <td>1.414646</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413800</td>
#       <td>1.414585</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412300</td>
#       <td>1.414575</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.414000</td>
#       <td>1.414574</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 16, 'weight_decay': 0.1}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 21:06, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449995</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443400</td>
#       <td>1.446848</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442822</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439200</td>
#       <td>1.438962</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434700</td>
#       <td>1.435271</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432700</td>
#       <td>1.431836</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427800</td>
#       <td>1.428730</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425500</td>
#       <td>1.425944</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420600</td>
#       <td>1.423455</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420600</td>
#       <td>1.421341</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.420000</td>
#       <td>1.419526</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.418000</td>
#       <td>1.418033</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416300</td>
#       <td>1.416818</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414600</td>
#       <td>1.415901</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.416000</td>
#       <td>1.415255</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414300</td>
#       <td>1.414834</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413900</td>
#       <td>1.414646</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413800</td>
#       <td>1.414585</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412300</td>
#       <td>1.414575</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.414000</td>
#       <td>1.414574</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.01}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 21:07, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449990</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443300</td>
#       <td>1.446825</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442777</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439100</td>
#       <td>1.438895</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434600</td>
#       <td>1.435184</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432600</td>
#       <td>1.431730</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427700</td>
#       <td>1.428608</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425400</td>
#       <td>1.425806</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420500</td>
#       <td>1.423305</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420500</td>
#       <td>1.421180</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.419900</td>
#       <td>1.419355</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.417800</td>
#       <td>1.417855</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416100</td>
#       <td>1.416634</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414500</td>
#       <td>1.415713</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.415900</td>
#       <td>1.415064</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414100</td>
#       <td>1.414640</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413700</td>
#       <td>1.414451</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413600</td>
#       <td>1.414389</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412100</td>
#       <td>1.414379</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.413900</td>
#       <td>1.414378</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.05}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 21:10, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449990</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443300</td>
#       <td>1.446825</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442777</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439100</td>
#       <td>1.438895</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434600</td>
#       <td>1.435184</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432600</td>
#       <td>1.431730</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427700</td>
#       <td>1.428608</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425400</td>
#       <td>1.425806</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420500</td>
#       <td>1.423305</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420500</td>
#       <td>1.421180</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.419900</td>
#       <td>1.419355</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.417800</td>
#       <td>1.417855</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416100</td>
#       <td>1.416634</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414500</td>
#       <td>1.415713</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.415900</td>
#       <td>1.415064</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414100</td>
#       <td>1.414640</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413700</td>
#       <td>1.414451</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413600</td>
#       <td>1.414389</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412100</td>
#       <td>1.414379</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.413900</td>
#       <td>1.414378</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 32, 'weight_decay': 0.1}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='10000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10000/10000 20:29, Epoch 20/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.447500</td>
#       <td>1.449990</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.443300</td>
#       <td>1.446825</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.442000</td>
#       <td>1.442777</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.439100</td>
#       <td>1.438895</td>
#       <td>{'accuracy': 0.2695}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.434600</td>
#       <td>1.435184</td>
#       <td>{'accuracy': 0.27}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.432600</td>
#       <td>1.431730</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.427700</td>
#       <td>1.428608</td>
#       <td>{'accuracy': 0.2715}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.425400</td>
#       <td>1.425806</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.420500</td>
#       <td>1.423305</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.420500</td>
#       <td>1.421180</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.419900</td>
#       <td>1.419355</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.417800</td>
#       <td>1.417855</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.416100</td>
#       <td>1.416634</td>
#       <td>{'accuracy': 0.271}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.414500</td>
#       <td>1.415713</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.415900</td>
#       <td>1.415064</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.414100</td>
#       <td>1.414640</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.413700</td>
#       <td>1.414451</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.413600</td>
#       <td>1.414389</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.412100</td>
#       <td>1.414379</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.413900</td>
#       <td>1.414378</td>
#       <td>{'accuracy': 0.2705}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2695}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.27}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2715}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.271}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2705}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2875}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 1e-08, 'lora_alpha': 64, 'weight_decay': 0.01}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# ...
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.314900</td>
#       <td>1.678069</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.754800</td>
#       <td>1.370566</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.868800</td>
#       <td>2.590081</td>
#       <td>{'accuracy': 0.1655}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.949500</td>
#       <td>2.552879</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.806300</td>
#       <td>2.088812</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.1655}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.324}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 0.01, 'lora_alpha': 32, 'weight_decay': 0.05}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='2000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2000/10000 04:06 < 16:26, 8.11 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.322600</td>
#       <td>1.716700</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.804900</td>
#       <td>2.178100</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.860600</td>
#       <td>1.964366</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.797100</td>
#       <td>1.838146</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.285}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 0.01, 'lora_alpha': 32, 'weight_decay': 0.1}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='2000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2000/10000 04:07 < 16:30, 8.08 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.342000</td>
#       <td>1.392819</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.747800</td>
#       <td>1.497889</td>
#       <td>{'accuracy': 0.2685}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.881500</td>
#       <td>1.825258</td>
#       <td>{'accuracy': 0.1655}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.847500</td>
#       <td>2.125883</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.2685}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.1655}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.324}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.01}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='2000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2000/10000 04:06 < 16:27, 8.10 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.423200</td>
#       <td>1.549998</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.761500</td>
#       <td>1.574850</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.947600</td>
#       <td>2.000189</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.961800</td>
#       <td>2.080742</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.2265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.05}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='3500' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 3500/10000 07:13 < 13:24, 8.08 it/s, Epoch 7/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.384000</td>
#       <td>1.624360</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.824600</td>
#       <td>1.628683</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.896500</td>
#       <td>1.798299</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.842300</td>
#       <td>1.591814</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.802600</td>
#       <td>2.198066</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.852600</td>
#       <td>1.947862</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.832800</td>
#       <td>2.302438</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.324}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# Evaluating {'learning_rate': 0.01, 'lora_alpha': 64, 'weight_decay': 0.1}...
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='2000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 2000/10000 04:08 < 16:33, 8.05 it/s, Epoch 4/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.374000</td>
#       <td>1.700065</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.844800</td>
#       <td>1.830787</td>
#       <td>{'accuracy': 0.239}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.898400</td>
#       <td>2.194844</td>
#       <td>{'accuracy': 0.269}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.921600</td>
#       <td>2.416014</td>
#       <td>{'accuracy': 0.3265}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.239}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.269}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.3265}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
#     <div>
#
#       <progress value='63' max='63' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63/63 00:03]
#     </div>
# Trainer is attempting to log a value of "{'accuracy': 0.285}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Best params: {'learning_rate': 0.0001, 'lora_alpha': 64, 'weight_decay': 0.01}
# Best score: 0.902

# %%
print(f"Best params: {best_params}")
print(f"Best score: {best_score}")
# Out:
# Best params: {'learning_rate': 0.0001, 'lora_alpha': 64, 'weight_decay': 0.01}
# Best score: 0.902

# %% [markdown]
# ## Training BERT4RE with the best hyperparamters and saving the model

# %%
# import accuracy evaluation metric
accuracy = evaluate.load("accuracy")


# define an evaluation function to pass into trainer later
def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=1)

    return {"accuracy": accuracy.compute(predictions=predictions, references=labels)}

# LoRA config
peft_config = LoraConfig(task_type="SEQ_CLS",
                    r=4,
                    lora_alpha=best_params['lora_alpha'],
                    lora_dropout=0.1,
                    target_modules = ["attention.self.query", "attention.self.key","attention.self.value"])

model_checkpoint = 'thearod5/bert4re'

# generate classification model from model_checkpoint
model = AutoModelForSequenceClassification.from_pretrained(
    model_checkpoint, num_labels=4, id2label=id2label, label2id=label2id)

model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Add EarlyStoppingCallback to the trainer
early_stopping = EarlyStoppingCallback(early_stopping_patience=3)

# Create training arguments
training_args = TrainingArguments(
    output_dir= model_checkpoint + "-lora-text-classification",
    learning_rate=best_params['learning_rate'],
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=20,
    weight_decay=best_params['weight_decay'],
    evaluation_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    lr_scheduler_type="cosine",  # learning rate scheduler type
    warmup_ratio=0.1  # warmup ratio for lr scheduler
)

# Create the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    callbacks=[early_stopping]
)

# Train the model
trainer.train()
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at thearod5/bert4re and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Detected kernel version 3.10.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# trainable params: 704,260 || all params: 68,798,216 || trainable%: 1.0237
# Using device: cuda
#     <div>
#
#       <progress value='9000' max='10000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 9000/10000 18:36 < 02:04, 8.06 it/s, Epoch 18/20]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.284900</td>
#       <td>1.214867</td>
#       <td>{'accuracy': 0.4885}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.963400</td>
#       <td>0.712026</td>
#       <td>{'accuracy': 0.7665}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.624800</td>
#       <td>0.630486</td>
#       <td>{'accuracy': 0.8105}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.516100</td>
#       <td>0.515433</td>
#       <td>{'accuracy': 0.8395}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.457400</td>
#       <td>0.497671</td>
#       <td>{'accuracy': 0.8575}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.427100</td>
#       <td>0.459406</td>
#       <td>{'accuracy': 0.8615}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.387100</td>
#       <td>0.431806</td>
#       <td>{'accuracy': 0.872}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.363300</td>
#       <td>0.419685</td>
#       <td>{'accuracy': 0.878}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.338000</td>
#       <td>0.391460</td>
#       <td>{'accuracy': 0.8825}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.317500</td>
#       <td>0.360574</td>
#       <td>{'accuracy': 0.89}</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.298100</td>
#       <td>0.360209</td>
#       <td>{'accuracy': 0.891}</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.287500</td>
#       <td>0.362121</td>
#       <td>{'accuracy': 0.892}</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.275900</td>
#       <td>0.355192</td>
#       <td>{'accuracy': 0.8955}</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.267800</td>
#       <td>0.364307</td>
#       <td>{'accuracy': 0.8955}</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.261800</td>
#       <td>0.350440</td>
#       <td>{'accuracy': 0.8975}</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.256400</td>
#       <td>0.352667</td>
#       <td>{'accuracy': 0.898}</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.255500</td>
#       <td>0.351267</td>
#       <td>{'accuracy': 0.898}</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.253300</td>
#       <td>0.352260</td>
#       <td>{'accuracy': 0.8995}</td>
#     </tr>
#   </tbody>
# </table><p>
# Trainer is attempting to log a value of "{'accuracy': 0.4885}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.7665}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8105}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8395}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8575}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8615}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.872}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.878}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8825}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.89}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.891}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.892}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8955}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8955}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8975}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.898}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.898}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# Trainer is attempting to log a value of "{'accuracy': 0.8995}" of type <class 'dict'> for key "eval/accuracy" as a scalar. This invocation of Tensorboard's writer.add_scalar() is incorrect so we dropped this attribute.
# TrainOutput(global_step=9000, training_loss=0.4353422554863824, metrics={'train_runtime': 1116.4639, 'train_samples_per_second': 286.601, 'train_steps_per_second': 8.957, 'total_flos': 1.4443123955304288e+16, 'train_loss': 0.4353422554863824, 'epoch': 18.0})

# %% [markdown]
# ### Testing the model on the test set
#
# Along with accuracy, we evaluate the model using Micro F1 score as the dataset is imbalanced. We also print the classification report

# %%
# Reinitialize accuracy metric to avoid potential overwrite issues
accuracy = evaluate.load("accuracy")

# Get predictions and true labels
predictions = trainer.predict(tokenized_dataset["test"])
preds = np.argmax(predictions.predictions, axis=1)
labels = predictions.label_ids

# Compute metrics
# Compute accuracy
accuracy = accuracy.compute(predictions=preds, references=labels)["accuracy"]
precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average="micro")

# Print the metrics
print(f"Test Accuracy: {accuracy:.4f}")
print(f"Test Micro Precision: {precision:.4f}")
print(f"Test Micro Recall: {recall:.4f}")
print(f"Test Micro F1-score: {f1:.4f}")

# Print classification report
class_report = classification_report(labels, preds, target_names=[id2label[i] for i in range(4)])
print("\nClassification Report:\n")
print(class_report)
# Out:
# Test Accuracy: 0.9085
# Test Micro Precision: 0.9085
# Test Micro Recall: 0.9085
# Test Micro F1-score: 0.9085
#
# Classification Report:
#
#                  precision    recall  f1-score   support
#
#      bug report       0.86      0.85      0.86       329
# feature request       0.92      0.85      0.88       453
#          rating       0.91      0.93      0.92       570
# user experience       0.92      0.96      0.94       648
#
#        accuracy                           0.91      2000
#       macro avg       0.90      0.90      0.90      2000
#    weighted avg       0.91      0.91      0.91      2000

# %% [markdown]
# A couple of functions are defined below that would be used while making a single prediction

# %%
def preprocess_input(text, tokenizer):
    #tokenize and truncate text
    tokenizer.truncation_side = "left"
    tokenized_inputs = tokenizer(
        text,
        return_tensors="pt",
        truncation=True,
        max_length=512
    )

    return tokenized_inputs
def predict(text, model, tokenizer):
    model.eval()  # Set the model to evaluation mode
    inputs = preprocess_input(text, tokenizer)

    # Move inputs to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        probabilities = torch.softmax(logits, dim=1)
        predicted_class = torch.argmax(probabilities, dim=1).item()
        confidence = probabilities[0, predicted_class].item()

    return id2label[predicted_class], confidence

# %%
# Example usage
texts = ["This app has an amazing feature called voice search. You can literaly use your voice to search for something",
        "I do not like the theme of this app, otherwise the app is great",
        "good app",
        "Please put a search bar in the home page to search for all documents",
        "The coins do not update in the account after buying it from the store"]
for text in texts:
    predicted_class, confidence = predict(text, model, tokenizer)
    print(f"Predicted Class: {predicted_class}, Confidence: {confidence:.4f}")
# Out:
# Predicted Class: feature request, Confidence: 0.9946
# Predicted Class: bug report, Confidence: 0.3619
# Predicted Class: rating, Confidence: 0.8977
# Predicted Class: feature request, Confidence: 0.9746
# Predicted Class: bug report, Confidence: 0.9382

# %% [markdown]
# ## Saving the model and tokenizer

# %%
output_dir = "./bert4re_model"
trainer.save_model(output_dir)
tokenizer.save_pretrained(output_dir)
# Out:
# ('./bert4re_model/tokenizer_config.json',
#  './bert4re_model/special_tokens_map.json',
#  './bert4re_model/vocab.json',
#  './bert4re_model/merges.txt',
#  './bert4re_model/added_tokens.json',
#  './bert4re_model/tokenizer.json')

# %% [markdown]
# ## Loading the saved model and tokenizer

# %%
model_dir = "./bert4re_model"
tokenizer = AutoTokenizer.from_pretrained(model_dir, add_prefix_space=True)
loaded_model = AutoModelForSequenceClassification.from_pretrained(
    model_dir, num_labels=4, id2label=id2label, label2id=label2id)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at thearod5/bert4re and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Example usage with the loaded model and tokenizer
texts = ["This app has an amazing feature called voice search. You can literaly use your voice to search for something",
        "I do not like the theme of this app, otherwise the app is great",
        "good app",
        "Please put a search bar in the home page to search for all documents",
        "The coins do not update in the account after buying it from the store"]
for text in texts:
    predicted_class, confidence = predict(text, loaded_model, tokenizer)
    print(f"Predicted Class: {predicted_class}, Confidence: {confidence:.4f}")
# Out:
# Predicted Class: feature request, Confidence: 0.9946
# Predicted Class: bug report, Confidence: 0.3619
# Predicted Class: rating, Confidence: 0.8977
# Predicted Class: feature request, Confidence: 0.9746
# Predicted Class: bug report, Confidence: 0.9382
